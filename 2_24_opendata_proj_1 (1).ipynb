# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# 1                      6.3                         15
# 2                     11.1                          8
# 3                        s                          s
# 4                        s                          s
#
#   Percent Scoring 65 or Above Number Scoring 80 or Above  \
# 0                           s                          s
# 1                        93.8                          7
# 2                        88.9                          2
# 3                           s                          s
# 4                           s                          s
#
#   Percent Scoring 80 or Above Number Scoring CR Percent Scoring CR
# 0                           s                na                 na
# 1                        43.8                na                 na
# 2                        22.2                na                 na
# 3                           s                na                 na
# 4                           s                na                 na

# %% [markdown]
# the goal of this project is to analyze student test performance
#
# pick any school in this dataset as an initial comparison point
#
# pick a feature/measure/score
#
# compare above school to schools in the entire dataset, schools in a particular borough, or schools in a particular district - you only need to do one additional comparison point (but you’re welcome to do more comparisons if you feel compelled to do so)
#
# the analysis should include some descriptive statistics
#
# the analysis should include one cleaning task (or more)
#
# the analysis should include one visualization (or more)
#
# the analysis should include a brief conclusion statement (not more than two or three sentences)

# %%
#look at the first 20 rows
df.head(20)
# Out:
#    School DBN                     School Name School Level  \
# 0      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3      01M140          P.S. 140 Nathan Straus          K-8
# 4      01M140          P.S. 140 Nathan Straus          K-8
# 5      01M140          P.S. 140 Nathan Straus          K-8
# 6      01M140          P.S. 140 Nathan Straus          K-8
# 7      01M140          P.S. 140 Nathan Straus          K-8
# 8      01M184            P.S. 184m Shuang Wen          K-8
# 9      01M184            P.S. 184m Shuang Wen          K-8
# 10     01M184            P.S. 184m Shuang Wen          K-8
# 11     01M184            P.S. 184m Shuang Wen          K-8
# 12     01M188      P.S. 188 The Island School          K-8
# 13     01M188      P.S. 188 The Island School          K-8
# 14     01M188      P.S. 188 The Island School          K-8
# 15     01M188      P.S. 188 The Island School          K-8
# 16     01M188      P.S. 188 The Island School          K-8
# 17     01M188      P.S. 188 The Island School          K-8
# 18     01M292      Orchard Collegiate Academy  High school
# 19     01M292      Orchard Collegiate Academy  High school
#
#              Regents Exam  Year  Total Tested Mean Score  \
# 0     Common Core Algebra  2017             4          s
# 1      Living Environment  2015            16       77.9
# 2      Living Environment  2016             9         74
# 3     Common Core Algebra  2016             3          s
# 4     Common Core Algebra  2017             2          s
# 5      Living Environment  2015             9       67.4
# 6      Living Environment  2016            15       72.6
# 7      Living Environment  2017             9       64.4
# 8     Common Core Algebra  2015            49       78.4
# 9     Common Core Algebra  2016            51         79
# 10    Common Core Algebra  2017            51       84.8
# 11     Living Environment  2017            55       83.9
# 12    Common Core Algebra  2015            23       62.9
# 13    Common Core Algebra  2016            22         69
# 14    Common Core Algebra  2017            20       67.4
# 15    Common Core English  2016             1          s
# 16     Living Environment  2016            17       62.1
# 17     Living Environment  2017             3          s
# 18  Algebra2/Trigonometry  2015             5          s
# 19  Algebra2/Trigonometry  2016             5          s
#
#    Number Scoring Below 65 Percent Scoring Below 65  \
# 0                        s                        s
# 1                        1                      6.3
# 2                        1                     11.1
# 3                        s                        s
# 4                        s                        s
# 5                        3                     33.3
# 6                        2                     13.3
# 7                        5                     55.6
# 8                        1                        2
# 9                        9                     17.6
# 10                       0                        0
# 11                       1                      1.8
# 12                      14                     60.9
# 13                       6                     27.3
# 14                       7                       35
# 15                       s                        s
# 16                       9                     52.9
# 17                       s                        s
# 18                       s                        s
# 19                       s                        s
#
#    Number Scoring 65 or Above Percent Scoring 65 or Above  \
# 0                           s                           s
# 1                          15                        93.8
# 2                           8                        88.9
# 3                           s                           s
# 4                           s                           s
# 5                           6                        66.7
# 6                          13                        86.7
# 7                           4                        44.4
# 8                          48                          98
# 9                          42                        82.4
# 10                         51                         100
# 11                         54                        98.2
# 12                          9                        39.1
# 13                         16                        72.7
# 14                         13                          65
# 15                          s                           s
# 16                          8                        47.1
# 17                          s                           s
# 18                          s                           s
# 19                          s                           s
#
#    Number Scoring 80 or Above Percent Scoring 80 or Above Number Scoring CR  \
# 0                           s                           s                na
# 1                           7                        43.8                na
# 2                           2                        22.2                na
# 3                           s                           s                na
# 4                           s                           s                na
# 5                           0                           0                na
# 6                           5                        33.3                na
# 7                           1                        11.1                na
# 8                          23                        46.9                48
# 9                          33                        64.7                40
# 10                         44                        86.3                50
# 11                         43                        78.2                na
# 12                          0                           0                 2
# 13                          2                         9.1                15
# 14                          1                           5                10
# 15                          s                           s                na
# 16                          0                           0                na
# 17                          s                           s                na
# 18                          s                           s                na
# 19                          s                           s                na
#
#    Percent Scoring CR
# 0                  na
# 1                  na
# 2                  na
# 3                  na
# 4                  na
# 5                  na
# 6                  na
# 7                  na
# 8                  98
# 9                78.4
# 10                 98
# 11                 na
# 12                8.7
# 13               68.2
# 14                 50
# 15                 na
# 16                 na
# 17                 na
# 18                 na
# 19                 na

# %%
#bottom 20 rows
df.tail(20)
# Out:
#        School DBN                    School Name School Level  \
# 212311     84X706  Harriet Tubman Charter School          K-8
# 212312     84X706  Harriet Tubman Charter School          K-8
# 212313     84X706  Harriet Tubman Charter School          K-8
# 212314     84X706  Harriet Tubman Charter School          K-8
# 212315     84X706  Harriet Tubman Charter School          K-8
# 212316     84X706  Harriet Tubman Charter School          K-8
# 212317     84X706  Harriet Tubman Charter School          K-8
# 212318     84X717           Icahn Charter School          K-8
# 212319     84X717           Icahn Charter School          K-8
# 212320     84X717           Icahn Charter School          K-8
# 212321     84X717           Icahn Charter School          K-8
# 212322     84X717           Icahn Charter School          K-8
# 212323     84X717           Icahn Charter School          K-8
# 212324     84X717           Icahn Charter School          K-8
# 212325     84X717           Icahn Charter School          K-8
# 212326     84X717           Icahn Charter School          K-8
# 212327     84X717           Icahn Charter School          K-8
# 212328     84X717           Icahn Charter School          K-8
# 212329     84X717           Icahn Charter School          K-8
# 212330     84X717           Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 212311          Common Core Algebra  2017            15       82.6
# 212312          Common Core Algebra  2017             7          s
# 212313          Common Core Algebra  2017             1          s
# 212314           Integrated Algebra  2015            13          s
# 212315           Integrated Algebra  2015             3          s
# 212316           Living Environment  2015             1          s
# 212317  U.S. History and Government  2017             3          s
# 212318          Common Core Algebra  2015             5          s
# 212319          Common Core Algebra  2015             2          s
# 212320          Common Core Algebra  2016             8       87.9
# 212321          Common Core Algebra  2016             6       87.2
# 212322          Common Core Algebra  2017             6         87
# 212323          Common Core Algebra  2017             6       88.3
# 212324           Living Environment  2015             8       76.5
# 212325           Living Environment  2015             6       79.8
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 212311                       0                        0
# 212312                       s                        s
# 212313                       s                        s
# 212314                       s                        s
# 212315                       s                        s
# 212316                       s                        s
# 212317                       s                        s
# 212318                       s                        s
# 212319                       s                        s
# 212320                       0                        0
# 212321                       0                        0
# 212322                       0                        0
# 212323                       0                        0
# 212324                       1                     12.5
# 212325                       0                        0
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# 212329                       s                        s
# 212330                       s                        s
#
#        Number Scoring 65 or Above Percent Scoring 65 or Above  \
# 212311                         15                         100
# 212312                          s                           s
# 212313                          s                           s
# 212314                          s                           s
# 212315                          s                           s
# 212316                          s                           s
# 212317                          s                           s
# 212318                          s                           s
# 212319                          s                           s
# 212320                          8                         100
# 212321                          6                         100
# 212322                          6                         100
# 212323                          6                         100
# 212324                          7                        87.5
# 212325                          6                         100
# 212326                          s                           s
# 212327                          s                           s
# 212328                          s                           s
# 212329                          s                           s
# 212330                          s                           s
#
#        Number Scoring 80 or Above Percent Scoring 80 or Above  \
# 212311                         12                          80
# 212312                          s                           s
# 212313                          s                           s
# 212314                          s                           s
# 212315                          s                           s
# 212316                          s                           s
# 212317                          s                           s
# 212318                          s                           s
# 212319                          s                           s
# 212320                          7                        87.5
# 212321                          6                         100
# 212322                          6                         100
# 212323                          5                        83.3
# 212324                          2                          25
# 212325                          2                        33.3
# 212326                          s                           s
# 212327                          s                           s
# 212328                          s                           s
# 212329                          s                           s
# 212330                          s                           s
#
#        Number Scoring CR Percent Scoring CR
# 212311                15                100
# 212312                na                 na
# 212313                na                 na
# 212314                na                 na
# 212315                na                 na
# 212316                na                 na
# 212317                na                 na
# 212318                na                 na
# 212319                na                 na
# 212320                 8                100
# 212321                 6                100
# 212322                 6                100
# 212323                 6                100
# 212324                na                 na
# 212325                na                 na
# 212326                na                 na
# 212327                na                 na
# 212328                na                 na
# 212329                na                 na
# 212330                na                 na

# %%
#check rows, columns numbers
df.shape
# Out:
# (212331, 15)

# %%
#data types and missing values; most things are an object (after cleaning; initially mean was object)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212331 entries, 0 to 212330
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   School DBN                   212331 non-null  object
#  1   School Name                  212331 non-null  object
#  2   School Level                 212331 non-null  object
#  3   Regents Exam                 212321 non-null  object
#  4   Year                         212331 non-null  int64
#  5   Total Tested                 212331 non-null  int64
#  6   Mean Score                   212331 non-null  object
#  7   Number Scoring Below 65      212331 non-null  object
#  8   Percent Scoring Below 65     212331 non-null  object
#  9   Number Scoring 65 or Above   212331 non-null  object
#  10  Percent Scoring 65 or Above  212331 non-null  object
#  11  Number Scoring 80 or Above   212331 non-null  object
#  12  Percent Scoring 80 or Above  212331 non-null  object
#  13  Number Scoring CR            212331 non-null  object
#  14  Percent Scoring CR           212331 non-null  object
# dtypes: int64(2), object(13)
# memory usage: 24.3+ MB

# %%
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
print(df.head())
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# 1                      6.3                         15
# 2                     11.1                          8
# 3                        s                          s
# 4                        s                          s
#
#   Percent Scoring 65 or Above Number Scoring 80 or Above  \
# 0                           s                          s
# 1                        93.8                          7
# 2                        88.9                          2
# 3                           s                          s
# 4                           s                          s
#
#   Percent Scoring 80 or Above Number Scoring CR Percent Scoring CR
# 0                           s                na                 na
# 1                        43.8                na                 na
# 2                        22.2                na                 na
# 3                           s                na                 na
# 4                           s                na                 na

# %%
#for things I expect to be a number like mean score,
#I want to convert it to a number instead of object
#so I'm checking why it's an object
#looks like there's a "s" in the first line
df['Mean Score'].unique()
# Out:
# array(['s', '77.9', '74', '67.4', '72.6', '64.4', '78.4', '79', '84.8',
#        '83.9', '62.9', '69', '62.1', '52.3', '63.9', '67.5', '48', '61.5',
#        '67.2', '77.2', '49.2', '56.8', '63', '51.6', '57.8', '54.2',
#        '59.8', '59.3', '63.4', '51.7', '55.4', '63.2', '65', '45', '45.3',
#        '53.4', '71.7', '56.2', '71.9', '80.7', '78', '72.9', '62.2',
#        '58.6', '62.6', '68.2', '67.3', '64.9', '69.2', '73.9', '73.1',
#        '56.4', '60.9', '65.1', '57.1', '68.5', '55.1', '65.8', '68', '72',
#        '65.7', '71.8', '67.7', '69.8', '72.7', '64.8', '72.1', '70.5',
#        '76.7', '76.9', '78.2', '79.5', '82.2', '79.7', '74.6', '71.2',
#        '49.3', '60.5', '64.5', '61.6', '42', '50.1', '52.2', '57.3',
#        '54.8', '44.3', '51', '74.2', '50.9', '61.3', '65.5', '59.9',
#        '51.8', '64', '55.3', '62.8', '54.4', '57', '60.3', '64.1', '63.7',
#        '73.5', '50.5', '59.7', '39.6', '79.1', '85.4', '77.7', '78.1',
#        '77', '70.2', '76', '74.3', '71', '73.7', '80.6', '77.6', '77.1',
#        '75.3', '71.6', '80', '81', '84', '80.8', '81.2', '78.3', '83.1',
#        '76.2', '93.5', '87.7', '88.1', '80.9', '79.3', '89.6', '83.6',
#        '66.3', '87.2', '88.5', '90.6', '87.3', '80.1', '80.5', '87.4',
#        '89.5', '89.9', '84.1', '76.1', '78.5', '91', '90.9', '92.3',
#        '61.4', '70.6', '65.2', '73.8', '67.6', '65.9', '66.8', '67.1',
#        '55.9', '73.3', '73.4', '72.5', '81.5', '79.6', '91.7', '89.8',
#        '83.4', '82.9', '86.5', '79.2', '88', '86.4', '77.4', '83.8', '53',
#        '34.6', '38.4', '57.6', '58.9', '69.3', '54', '61.9', '75.9',
#        '53.2', '54.1', '56.6', '49', '55.6', '51.4', '57.2', '61.2',
#        '59.5', '56.3', '65.3', '69.5', '45.2', '70.3', '69.9', '70.7',
#        '84.2', '87.5', '87', '91.9', '94.1', '81.3', '79.9', '84.3',
#        '90.4', '44', '40.1', '62.3', '83.5', '76.5', '72.8', '59', '53.6',
#        '65.6', '59.1', '75.4', '67.9', '62.4', '78.8', '62.5', '59.2',
#        '51.1', '48.5', '43.6', '50.8', '49.8', '60.1', '63.3', '56.5',
#        '58.7', '58.4', '86.9', '93.4', '89.1', '85.5', '57.4', '73',
#        '88.6', '82', '81.8', '78.7', '85', '85.7', '85.1', '89.7', '44.1',
#        '68.7', '64.2', '70.8', '75.8', '75.1', '72.3', '75.6', '74.8',
#        '82.4', '47.8', '66.7', '63.5', '79.4', '75.2', '53.1', '57.7',
#        '75.7', '71.3', '45.9', '43.2', '43.1', '48.8', '53.3', '66.1',
#        '67', '60.4', '62.7', '46.9', '56', '75', '71.5', '75.5', '73.2',
#        '66.9', '74.5', '43.5', '41.1', '67.8', '54.3', '76.3', '74.4',
#        '52.1', '68.8', '61', '58.2', '55.7', '71.4', '58.8', '83', '54.5',
#        '70.4', '69.1', '64.3', '68.1', '63.6', '49.6', '86.6', '87.6',
#        '52.6', '47.5', '56.1', '59.6', '66.4', '58.3', '64.7', '68.3',
#        '60', '66.6', '71.1', '65.4', '63.1', '66.2', '76.4', '36.1',
#        '61.8', '48.4', '55.2', '76.6', '70.1', '70', '59.4', '68.6',
#        '84.5', '93.7', '69.4', '50.6', '30.8', '33.3', '60.8', '43.9',
#        '44.7', '54.9', '52.5', '46.4', '52', '46.2', '55', '68.4', '60.6',
#        '86.2', '82.7', '85.2', '84.7', '46.1', '52.4', '66', '77.3',
#        '66.5', '57.5', '54.7', '83.2', '37.3', '61.7', '49.5', '43.8',
#        '63.8', '80.3', '73.6', '76.8', '70.9', '91.8', '89', '44.9',
#        '64.6', '74.1', '68.9', '53.8', '48.6', '61.1', '60.7', '56.7',
#        '86.1', '82.1', '77.5', '80.4', '74.7', '78.6', '81.7', '74.9',
#        '89.3', '78.9', '86.7', '90', '92.1', '81.6', '83.3', '85.6',
#        '72.2', '80.2', '72.4', '93.1', '93.6', '90.5', '57.9', '87.9',
#        '87.8', '82.6', '81.9', '77.8', '81.4', '82.8', '58.5', '85.9',
#        '91.6', '82.5', '88.2', '88.8', '90.7', '81.1', '94.3', '92.5',
#        '85.3', '88.9', '88.3', '91.3', '69.6', '48.1', '79.8', '46.5',
#        '51.3', '50.3', '62', '53.5', '34', '48.7', '51.9', '58', '35.2',
#        '58.1', '49.4', '44.5', '90.1', '88.4', '43.4', '52.7', '55.5',
#        '60.2', '50.2', '92.9', '82.3', '93.9', '92.4', '91.5', '93',
#        '94.9', '92.8', '88.7', '89.2', '96.4', '96.5', '96.8', '52.9',
#        '51.2', '46', '53.9', '41.2', '50.4', '46.7', '36.5', '87.1', '50',
#        '52.8', '48.2', '53.7', '54.6', '43.7', '42.9', '69.7', '49.1',
#        '45.5', '37.6', '55.8', '47', '37.9', '51.5', '56.9', '47.4',
#        '48.3', '86.3', '47.2', '38.3', '34.1', '85.8', '32.2', '30.4',
#        '49.7', '95.2', '46.3', '45.4', '92.7', '84.6', '92.6', '42.4',
#        '41.8', '84.9', '92', '90.2', '39.3', '41.6', '86.8', '36.4',
#        '42.1', '39.7', '84.4', '38.9', '97.1', '86', '45.1', '49.9',
#        '29.7', '48.9', '40.2', '44.4', '38.5', '41.9', '50.7', '89.4',
#        '90.3', '93.8', '95.4', '83.7', '35.3', '42.5', '40.6', '46.8',
#        '31.9', '47.6', '39.4', '39.2', '44.8', '45.8', '40.9', '47.3',
#        '45.7', '38.8', '38.1', '37.8', '46.6', '40.7', '44.6', '38',
#        '41.3', '30.9', '34.3', '40.4', '41', '34.9', '42.3', '47.9',
#        '33.1', '41.7', '23.5', '47.1', '47.7', '40.5', '91.4', '35.7',
#        '39.8', '45.6', '32', '26', '42.8', '31.8', '41.5', '40.3', '29.4',
#        '37.2', '36.8', '44.2', '94', '95.3', '96.6', '97.2', '96.7',
#        '95.9', '93.2', '94.8', '97.4', '97.6', '98.3', '90.8', '43',
#        '39.9', '37.7', '39.1', '38.6', '33.4', '42.7', '31.4', '37',
#        '41.4', '31.1', '40.8', '32.5', '91.1', '95.1', '32.6', '34.8',
#        '37.1', '36.2', '33.6', '35.9', '30.7', '35.6', '96.1', '95.8',
#        '43.3', '19.8', '38.7', '26.4', '38.2', '37.5', '39.5', '27.5',
#        '40', '25.2', '26.7', '34.2', '95', '29.5', '39', '33.8', '36.9',
#        '35.5', '93.3', '94.6', '35.8', '92.2', '32.1', '91.2', '35.4',
#        '96', '94.5', '95.5', '94.7', '42.6', '35.1', '25.9', '42.2',
#        '94.4', '30.1', '30.6', '34.7', '37.4', '33.5', '33.9', '32.8',
#        '24.9', '36.3', '36.6', '32.7', '36.7', '27.6', '36', '31.3',
#        '28.1', '33.7', '28.2', '31.5', '29.8', '27.8', '97.3', '34.4',
#        '29.3', '34.5', '26.3', '33.2', '20.3', '15', '24.1', '20.8', '29',
#        '26.6', '30.3', '23.9', '19.1', '28.7', '96.2', '26.2', '35',
#        '26.5', '24.3', '27.9', '94.2', '96.3', '96.9', '97.7', '32.3',
#        '27.1', '95.7', '33', '31.7', '28.9', '16.1', '31.2', '32.9',
#        '95.6', '97', '97.5', '98.5', '28', '28.5', '31', '25.6', '19.4',
#        '28.6', '27.3', '31.6', '30.5', '32.4', '27', '20.5', '25.7',
#        '21.6', '26.1', '98.4', '98.1', '29.9', '30.2', '29.2', '23.6',
#        '17.6', '24.7', '27.7', '26.9', '25.8', '23.7', '25.5', '29.6',
#        '21.7', '98.2', '97.8', '98.7', '98', '28.8', '15.7', '27.4', '25'],
#       dtype=object)

# %%
#cleaning up data
#convert s to number without messing with the mean

#printing clean mean data to see what rows have "s"
cleaned_meandata = df[df['Mean Score'] == 's']
print(cleaned_meandata)
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# 15         01M188      P.S. 188 The Island School          K-8
# 17         01M188      P.S. 188 The Island School          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 3               Common Core Algebra  2016             3          s
# 4               Common Core Algebra  2017             2          s
# 15              Common Core English  2016             1          s
# 17               Living Environment  2017             3          s
# ...                             ...   ...           ...        ...
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 0                            s                        s
# 3                            s                        s
# 4                            s                        s
# 15                           s                        s
# 17                           s                        s
# ...                        ...                      ...
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# 212329                       s                        s
# 212330                       s                        s
#
#        Number Scoring 65 or Above Percent Scoring 65 or Above  \
# 0                               s                           s
# 3                               s                           s
# 4                               s                           s
# 15                              s                           s
# 17                              s                           s
# ...                           ...                         ...
# 212326                          s                           s
# 212327                          s                           s
# 212328                          s                           s
# 212329                          s                           s
# 212330                          s                           s
#
#        Number Scoring 80 or Above Percent Scoring 80 or Above  \
# 0                               s                           s
# 3                               s                           s
# 4                               s                           s
# 15                              s                           s
# 17                              s                           s
# ...                           ...                         ...
# 212326                          s                           s
# 212327                          s                           s
# 212328                          s                           s
# 212329                          s                           s
# 212330                          s                           s
#
#        Number Scoring CR Percent Scoring CR
# 0                     na                 na
# 3                     na                 na
# 4                     na                 na
# 15                    na                 na
# 17                    na                 na
# ...                  ...                ...
# 212326                na                 na
# 212327                na                 na
# 212328                na                 na
# 212329                na                 na
# 212330                na                 na
#
# [75222 rows x 15 columns]

# %%
#using numpy to replace all the "s" with "nan"/NaN or not available number
#I would have replaced it with 0 but that will skew mean averages/numbers
df['Mean Score'] = df['Mean Score'].replace('s', np.nan)
df['Mean Score'] = df['Mean Score'].astype(float)
print("\nFirst 10 values in 'Mean Score':")
print(df['Mean Score'].head(10))
# Out:
# First 10 values in 'Mean Score':
# 0     NaN
# 1    77.9
# 2    74.0
# 3     NaN
# 4     NaN
# 5    67.4
# 6    72.6
# 7    64.4
# 8    78.4
# 9    79.0
# Name: Mean Score, dtype: float64

# %%
#Research question I want to ask: Which school performed better across the 3 years we got regents data for?
#choosing my schools for comparison

# %%
#looking for a specific school (hs)
#case ignores whether it's capitalized or lower case
#na=false tells pandas how to handle missing data/if there is missing data for school name
siths_results = df[df['School Name'].str.contains('Staten Island', case=False, na=False)]
print(siths_results['School Name'].unique())
# Out:
# ['The Eagle Academy for Young Men of Staten Island' 'Staten Island Yabc'
#  'Staten Island Technical High School'
#  'Staten Island School of Civic Leadership']

# %%
#looking for a specific school (hs competition)
#case ignores whether it's capitalized or lower case
#na=false tells pandas how to handle missing data/if there is missing data for school name
stuy_results = df[df['School Name'].str.contains('Stuy', case=False, na=False)]
print(stuy_results['School Name'].unique())
# Out:
# ['Stuyvesant High School' 'Bedford Stuyvesant Preparatory High School'
#  'Leadership Prep Bedford Stuyvesant Uncommon Prep C'
#  'Bedford Stuyvesant Collegiate Charter School'
#  'Bedford Stuyvesant New Beginnings Charter School']

# %%
#selecting schools for my analysis by listing out the two schools I want to compare

schools_of_interest = ['Staten Island Technical High School', 'Stuyvesant High School']
comparison_df = df[df['School Name'].isin(schools_of_interest)]
print(comparison_df['School Name'].unique())
# Out:
# ['Stuyvesant High School' 'Staten Island Technical High School']

# %%
#created subset for school to see scores
school1_df = df[df['School Name'] == 'Staten Island Technical High School']
print(school1_df['Regents Exam'].value_counts())
# Out:
# Regents Exam
# Living Environment              36
# Physical Settings/Chemistry     36
# Physical Settings/Physics       36
# Global History and Geography    36
# U.S. History and Government     35
# Common Core Algebra             35
# Common Core Geometry            34
# Algebra2/Trigonometry           24
# Common Core English             24
# Common Core Algebra2            23
# English                         12
# Geometry                        11
# Name: count, dtype: int64

# %%
#created subset for school for scores
school2_df = df[df['School Name'] == 'Stuyvesant High School']
print(school2_df['Regents Exam'].value_counts())
# Out:
# Regents Exam
# Common Core Geometry            38
# Living Environment              38
# Physical Settings/Physics       36
# Global History and Geography    36
# Physical Settings/Chemistry     36
# U.S. History and Government     36
# Common Core Algebra             35
# Algebra2/Trigonometry           24
# Common Core Algebra2            24
# Common Core English             24
# English                         19
# Geometry                        19
# Integrated Algebra              12
# Name: count, dtype: int64

# %%
#looks like my chosen above schools do not have too much data
#checking other options
print(df['School Name'].value_counts().head(30))
# Out:
# School Name
# New Visions Charter High School for Advanced Math     1337
# New Visions Charter High School for the Humanities    1031
# James Madison High School                              490
# Francis Lewis High School                              490
# Long Island City High School                           489
# Edward R. Murrow High School                           489
# John Dewey High School                                 488
# Forest Hills High School                               486
# Benjamin N. Cardozo High School                        486
# New Dorp High School                                   485
# John Bowne High School                                 484
# Tottenville High School                                484
# John Adams High School                                 484
# Robert H. Goddard High School of Communication Art     481
# Academy of Finance and Enterprise                      480
# New Utrecht High School                                480
# Port Richmond High School                              480
# Curtis High School                                     480
# Abraham Lincoln High School                            480
# New World High School                                  479
# Susan E. Wagner High School                            479
# Midwood High School                                    477
# Bayside High School                                    477
# DeWitt Clinton High School                             477
# Jamaica Gateway to the Sciences                        476
# Rachel Carson High School for Coastal Studies          476
# Fort Hamilton High School                              475
# William Cullen Bryant High School                      475
# Art and Design High School                             474
# High School for Construction Trades, Engineering a     473
# Name: count, dtype: int64

# %%
#other highschool comparisons in case my chosen schools don't work out
#schools_of_interest = ['John Dewey High School', 'New Dorp High School']
#comparison_df = df[df['School Name'].isin(schools_of_interest)]
#print(comparison_df['School Name'].unique())

# %%
#Comparison 1: mean score
#create subsets above for each school
#coercing ensures mean score is numeric before calculating. I did it above but
#redoing "coerce" here to change non numbers to NaN / readable
#using "group by" to compare both schools' mean scores/performance
comparison_df['Mean Score'] = pd.to_numeric(comparison_df['Mean Score'], errors='coerce')
print(comparison_df.groupby('School Name')['Mean Score'].describe())
#there were only 224 results for tech vs 271 results for stuy; not the most robust data comparison
# Out:
#                                      count       mean       std   min    25%  \
# School Name
# Staten Island Technical High School  224.0  88.862500  4.280577  77.4  85.50
# Stuyvesant High School               271.0  91.697786  3.353151  81.1  89.35
#
#                                       50%   75%   max
# School Name
# Staten Island Technical High School  88.9  92.1  96.3
# Stuyvesant High School               92.5  94.0  97.4
# /tmp/ipykernel_519/1689310206.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comparison_df['Mean Score'] = pd.to_numeric(comparison_df['Mean Score'], errors='coerce')

# %%
#to visualize the above:
#to explain:
# Stuyvesant performs better than SI Tech on average.
# the standard deviation for Stuy is relatively consistent at 3.35, meaning student
# performance was more consistent across different subjects
# the standard deviation for SI Tech is spread out more at 4.28. You can
# see how the box is bigger/taller than Stuy's in comparison.
sns.boxplot(data=comparison_df, x='School Name', y='Mean Score')
# Out:
# <Axes: xlabel='School Name', ylabel='Mean Score'>

# %% [markdown]
# Sentence explanation:
# Stuyvesant performs better than SI Tech on average. Student performance was more consistent across multiple school subjects at Stuyvesant High School (std: 3.35) than at Staten Island Technical High School (std: 4.28).

# %%
#looks at average score per school per year using seaborn and pandas
#question: is the performance of these schools improving, decreasing, or remaining stable over the years?
#create new dataframe and reset_index to turn year and school name into row labels/index 0 and 1 so seaborn can read and visualize correctly
yearly_avg = comparison_df.groupby(['Year', 'School Name'])['Mean Score'].mean().reset_index()

#hue = different colors for each school
#marker = dot on graph for the starting points of avg at beginning of school year
sns.lineplot(data=yearly_avg, x='Year', y='Mean Score', hue='School Name', marker='o')

plt.title('Trend of Average Regents Scores at the end of the School Year (2014-2017)')
plt.xlabel('Year in quarters')
plt.ylabel('Average Mean Score')
plt.grid(True)
plt.show()

# %% [markdown]
# Comparing Tech and Stuy's Regents performances across 3 school years (2014/2015, 2015/2016, 2016/2017) showed that they were consistent with one another though Stuy achieved a slightly higher average every year.
